# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_train = pd.read_csv('./train.csv',index_col = 'id')
df_test = pd.read_csv('./test.csv',index_col =  'id')
df_train.sample(5)
# Out:
#            keyword                   location  \
# id
# 672         attack   Scotland, United Kingdom
# 7463  obliteration                        NaN
# 3389    demolition  ÌÏT: 36.142163,-95.979189
# 3200        deluge      walking the tightrope
# 6955      massacre                        NaN
#
#                                                    text  target
# id
# 672   'Left hand side of a diamond is a graveyard sh...       0
# 7463               @tiggr_ why only Squad Obliteration?       1
# 3389  @samajp32 really needs to tone it down some in...       0
# 3200  Tomorrow is Internet Day. It has been almost 2...       0
# 6955  3 Years After the Sikh Temple Massacre Hate-Vi...       1

# %%
print("Train shape:", df_train.shape)
print("Test shape:", df_test.shape)
# Out:
# Train shape: (7613, 4)
# Test shape: (3263, 3)

# %%
for df in [df_train, df_test]:
    for col in df.columns:
        print(col,np.round(sum(df[col].isna())/len(df_train),4),'na value')
    print()
# Out:
# keyword 0.008 na value
# location 0.3327 na value
# text 0.0 na value
# target 0.0 na value
#
# keyword 0.0034 na value
# location 0.1451 na value
# text 0.0 na value

# %%
df_train.keyword.fillna("unknown",inplace=True)
df_train.location.fillna("unknown",inplace=True)
df_test.keyword.fillna("unknown",inplace=True)
df_test.location.fillna("unknown",inplace=True)

# %%
top30_loc = df_train.groupby(['location']).location.count().sort_values(ascending=False)[:30]

# %%
plt.figure(figsize = (6,10))
sns.barplot(x = top30_loc, y = top30_loc.index);
plt.xlabel('number of tweets');

# %%
temp = df_train.groupby(['target','keyword']).keyword.count()
plt.hist(temp.values)
# Out:
# (array([72., 53., 53., 47., 49., 50., 63., 33., 15.,  5.]),
#  array([ 1. ,  5.1,  9.2, 13.3, 17.4, 21.5, 25.6, 29.7, 33.8, 37.9, 42. ]),
#  <BarContainer object of 10 artists>)

# %%
df_train['target_mean'] = df_train.groupby('keyword')['target'].transform('mean')

fig = plt.figure(figsize=(8, 72), dpi=100)

sns.countplot(y=df_train.sort_values(by='target_mean', ascending=False)['keyword'],
              hue=df_train.sort_values(by='target_mean', ascending=False)['target'])

plt.tick_params(axis='x', labelsize=15)
plt.tick_params(axis='y', labelsize=12)
plt.legend(loc=1)
plt.title('Target Distribution in Keywords')

plt.show()

# %%
import spacy
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import regex as re
import string

nltk.download('stopwords')
nltk.download('punkt')

nltk_st = stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to /home/sina/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/sina/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
def clean(tweet, http = True, punc = True, lem = True, stop_w = True):
    
    if http is True:
        tweet = re.sub("https?:\/\/t.co\/[A-Za-z0-9]*", '', tweet)

    
#     tweet = [ strip_accents(word).lower() for word in word_tokenize(tweet)]
#     tweet = ' '.join(tweet)
    
    tweet = [word.lower() for word in word_tokenize(tweet) if not word.lower() in nltk_st]
    tweet = ' '.join(tweet)
    
    
    tweet = [word for word in word_tokenize(tweet) if len(word) > 3]
    tweet = ' '.join(tweet)
    
    
    for word in word_tokenize(tweet):
        if word == 'Û' :
            print(word)
    
    
#     for word in word_tokenize(tweet):
        
#     tweet = [word  ]
#     tweet = ' '.join(tweet)

    # lemmitizing
    if lem == True:
        lemmatized = [word.lemma_ for word in sp(tweet)]
        tweet = ' '.join(lemmatized)

    # punctuation removal
    if punc is True:
        tweet = tweet.translate(str.maketrans('', '', string.punctuation))
        
    # removing extra space
    tweet = re.sub("\s+", ' ', tweet)
    
    return tweet

# %%
df_train['cleaned_text'] = df_train.text.apply(lambda x: clean(x, lem = False, stop_w = 'nltk', http = True, punc = True))

# %%
import unicodedata
def strip_accents(s):
    return ''.join(c for c in unicodedata.normalize('NFD', s) if unicodedata.category(c) != 'Mn')
strip_accents("Hiroshima")
# Out:
# 'Hiroshima'

# %%
" ".join(df_train[df_train.target == 1].cleaned_text)
# Out:
# 'deeds reason earthquake allah forgive forest fire near ronge sask canada residents asked shelter place notified officers evacuation shelter place orders expected 13000 people receive wildfires evacuation orders california sent photo ruby alaska smoke wildfires pours school rockyfire update california closed directions lake county fire cafire wildfires flood disaster heavy rain causes flash flooding streets manitou colorado springs areas hill fire woods emergency evacuation happening building across street afraid tornado coming area three people died heat wave haha south tampa getting flooded hah wait second live south tampa fvck flooding raining flooding florida tampabay tampa days lost count flood bago myanmar arrived bago damage school multi crash breaking bbcmtd wholesale markets ablaze africanbaze breaking news nigeria flag ablaze inec office abia ablaze barbados bridgetown jamaica cars ablaze santa cruz head elizabeth police superintende west burned thousands wildfires ablaze california alone deputies shot brighton home ablaze wife years jail setting ablaze niece police arsonist deliberately black church north carolinaåêablaze kurds trampling turkmen flag later ablaze others vandalized offices turkmen front diyala truck ablaze voortrekker ave outside tambo intl cargo section west burned thousands wildfires ablaze california alone climate energy navista7 steve fires something else california tinderbox clown setting hood ablaze news24680 nxwestmidlands huge fire wholesale markets ablaze accident i24 nashvilletraffic traffic moving slower usual accident center lane blocked santaclara us101 great america pkwy bayarea traffic reported motor vehicle accident curry herman near stephenson involving overturned vehicle please bigrigradio live accident awareness i77 mile marker south mooresville iredell vehicle accident ramp closed 118 traffic accident cabrillo hwymagellan 080615 110358 i77 mile marker south mooresville iredell vehicle accident congestion 118 pastor scene accident owner range rover horrible accident past sunday finally able around thank truckcrash overturns fortworth interstate click crash accident ashville traffic carolina accident motorcyclist dies i540 crash crossed median motorcycle rider traveling accident property damage piner rdhorndale naayf first accident years turning onto chandanee magu near taxi rammed halfway turned everyone conf\x89û accident left lane blocked manchester eddy stop traffic back nh3a delay mins traffic accident property damage piner rdhorndale accident property damage 1600 17th 862015 209 traffic accident injury 2781 willis foreman aashiqui actress aggarwal nearfatal accident suffield alberta accident mile backup i77 south accident blocking right lanes exit langtree consider alternate breaking deadly motorcycle accident happened hagerstown today details your4state whag even week fucking accident fucking drive norwaymfa bahrain police previously died road accident killed explosion experts france begin examining airplane debris found reunion island french accident experts news strict liability context airplane accident pilot error common component aviation experts france begin examining airplane debris found reunion island french accident experts wedn alexalltimelow awwww airplane accident cuties good family members osama laden died airplane accident ironic mhmmm shit suspect goes airplane engine accident youtube horrible accident died wings airplane 29072015 cessna airplane accident ocampo coahuila mexico july 2015 killed four including state coahuila government official horrible accident died wings airplane 29072015 watchthevideo experts france begin examining airplane debris found reunion island french accident experts wednesday\x89û experts france begin examining airplane debris found reunion island french accident experts wednesday began examining votejkt48id mbataweel binladen family members killed airplane accident experts france begin examining airplane debris found reunion island ...

# %%
import unicodedata
from unidecode import unidecode

def deEmojify(inputString):
    returnString = ""

    for character in inputString:
        try:
            character.encode("ascii")
            returnString += character
        except UnicodeEncodeError:
            replaced = unidecode(str(character))
            if replaced != '':
                returnString += replaced
            else:
                try:
                     returnString += "[" + unicodedata.name(character) + "]"
                except ValueError:
                     returnString += "[x]"

    return returnString
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_7016/2205682855.py in <module>
#       1 import unicodedata
# ----> 2 from unidecode import unidecode
#       3
#       4 def deEmojify(inputString):
#       5     returnString = ""
#
# ModuleNotFoundError: No module named 'unidecode'

# %%
from wordcloud import WordCloud

plt.figure(figsize = (20,20)) 
wc = WordCloud(max_words = 2000 , width = 1600 , height = 800).generate(" ".join(df_train[df_train.target == 1].cleaned_text))
plt.imshow(wc , interpolation = 'bilinear')

# %%
target_count = df_train.target.value_counts()
plt.figure(figsize=(8,4))
plt.bar(['not a disaster','disaster'], target_count.values)
plt.title("Real disaster or not distribution")
# Out:
# Text(0.5, 1.0, 'Real disaster or not distribution')
